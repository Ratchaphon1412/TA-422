# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# from google.colab import drive
# drive.mount("/content/drive")

# %%
# ---
# Group No. 11
# นายเจษฎา ทิพลาภรุ่งโรจน์ 6410450397 
# นางสาว เบญญทิพย์ กีรติยาพร 6410450524
# นาย รุสลัน จงผดุงสัตย์ 6410450583
# นางสาว ศรัณย์รัชต์ วงค์น่วม 6410450605
# ---

problem = 2 # ปัญหาที่
data_num = 2 # ชุดข้อมูลที่

# ชุดข้อมูลเก็บใน /in
in_path = "./dataset/P"+str(problem)+"/in/"
data_path = in_path+"p"+str(problem)+"_input_dataset_"+str(data_num)+".txt"

# ผลลัพธ์เก็บใน /out
out_path = "./dataset/P"+str(problem)+"/out/"
result_path = out_path+"p"+str(problem)+"_output_"+str(data_num)+".csv"
png_path = out_path+"p"+str(problem)+"_plot_"+str(data_num)+".png"

# อ่านข้อมูล
data = pd.read_csv(data_path)

# --- เริ่มเขียนโค้ดตรงนี้ ---

# อ่านไฟล์ 'data.txt'
data = pd.read_csv('./dataset/P2/in/p2_input_dataset_1.txt', delimiter=r"\s+")

# สร้างกราฟแท่ง
plt.figure(figsize=(10, 6))  # ปรับขนาดกราฟ
data['Diagnosis'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Number of patients separated by diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Number of patients')
plt.xticks(rotation=0)  # หมุนแกน x ให้แสดงข้อมูลให้เหมาะสม
plt.tight_layout()  # ปรับระยะห่างในกราฟ
plt.show()



# --- สิ้นสุดโค้ดตรงนี้ ---

# เซฟผลลัพธ์
data.to_csv(result_path, index=False)

# แสดงผลลัพธ์
data.head()

# เซฟกราฟ
plt.savefig(png_path, dpi=100)

# แสดงผลกราฟ
plt.show()
